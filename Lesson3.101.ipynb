# %% [markdown]
# ## Import packages

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Upload the dataset to observe it

# %%
FrenchClothing = pd.read_excel('/Users/christinasimbenga/Desktop/Clothing.xlsx')

# %% [markdown]
# ## Check to see if it worked

# %%
FrenchClothing.head()
# Out:
#   category         subcategory  \
# 0    women            T-shirts
# 1    women      Soutiens-gorge
# 2    women  Pantalons & Shorts
# 3    women    Robes imprimÃ©es
# 4    women            T-shirts
#
#                                                 name  current_price  \
# 0  T-shirt boutonnÃ© Ã  manches courtes et imprim...          23.99
# 1      Plus Soutiens-gorge avec fermeture Ã  l'avant          15.99
# 2  Pantalon dÃ©contractÃ© Ã  taille Ã©lastique de...          25.99
# 3        Robe midi dÃ©contractÃ©e Ã  imprimÃ© floral          23.99
# 4                           T-shirt brodÃ© de fleurs          15.99
#
#    raw_price currency  discount  likes_count  is_new brand  ...  \
# 0      46.99      USD        49          313   False   NaN  ...
# 1      40.36      USD        60         4603   False   NaN  ...
# 2      50.99      USD        49         5564   False   NaN  ...
# 3      46.99      USD        49         1262   False   NaN  ...
# ...

# %% [markdown]
# ## Keep these categories

# %%
FrenchClothing1 = FrenchClothing[['subcategory', 'name', 'current_price', 'raw_price', 'discount', 'likes_count', 'is_new', 'brand', 'variation_0_color', 'variation_1_color', 'url', 'id', 'model']]

# %% [markdown]
# ## See if it works

# %%
FrenchClothing1.head()
# Out:
#           subcategory                                               name  \
# 0            T-shirts  T-shirt boutonnÃ© Ã  manches courtes et imprim...
# 1      Soutiens-gorge      Plus Soutiens-gorge avec fermeture Ã  l'avant
# 2  Pantalons & Shorts  Pantalon dÃ©contractÃ© Ã  taille Ã©lastique de...
# 3    Robes imprimÃ©es        Robe midi dÃ©contractÃ©e Ã  imprimÃ© floral
# 4            T-shirts                           T-shirt brodÃ© de fleurs
#
#    current_price  raw_price  discount  likes_count  is_new brand  \
# 0          23.99      46.99        49          313   False   NaN
# 1          15.99      40.36        60         4603   False   NaN
# 2          25.99      50.99        49         5564   False   NaN
# 3          23.99      46.99        49         1262   False   NaN
# 4          15.99      38.88        59         4485   False   NaN
#
#   variation_0_color variation_1_color  \
# 0             White              Navy
# 1             blanc              gris
# ...

# %% [markdown]
# ## Make columns for laymen

# %%
FrenchClothing1.rename(columns={'likes_count' : 'amount of likes'}, inplace=True)
# Out:
# /var/folders/b6/tn8p_f9d1ls_4qs2b7h32md00000gn/T/ipykernel_1373/3814093051.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   FrenchClothing1.rename(columns={'likes_count' : 'amount of likes'}, inplace=True)

# %% [markdown]
# ## See if it works

# %%
FrenchClothing1.head()
# Out:
#           subcategory                                               name  \
# 0            T-shirts  T-shirt boutonnÃ© Ã  manches courtes et imprim...
# 1      Soutiens-gorge      Plus Soutiens-gorge avec fermeture Ã  l'avant
# 2  Pantalons & Shorts  Pantalon dÃ©contractÃ© Ã  taille Ã©lastique de...
# 3    Robes imprimÃ©es        Robe midi dÃ©contractÃ©e Ã  imprimÃ© floral
# 4            T-shirts                           T-shirt brodÃ© de fleurs
#
#    current_price  raw_price  discount  amount of likes  is_new brand  \
# 0          23.99      46.99        49              313   False   NaN
# 1          15.99      40.36        60             4603   False   NaN
# 2          25.99      50.99        49             5564   False   NaN
# 3          23.99      46.99        49             1262   False   NaN
# 4          15.99      38.88        59             4485   False   NaN
#
#   variation_0_color variation_1_color  \
# 0             White              Navy
# ...

# %% [markdown]
# ## Rename more columns

# %%
FrenchClothing1.rename(columns={'is_new' : 'is new'}, inplace=True)
# Out:
# /var/folders/b6/tn8p_f9d1ls_4qs2b7h32md00000gn/T/ipykernel_1373/3786006619.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   FrenchClothing1.rename(columns={'is_new' : 'is new'}, inplace=True)

# %%
FrenchClothing1
# Out:
#               subcategory                                               name  \
# 0                T-shirts  T-shirt boutonnÃ© Ã  manches courtes et imprim...
# 1          Soutiens-gorge      Plus Soutiens-gorge avec fermeture Ã  l'avant
# 2      Pantalons & Shorts  Pantalon dÃ©contractÃ© Ã  taille Ã©lastique de...
# 3        Robes imprimÃ©es        Robe midi dÃ©contractÃ©e Ã  imprimÃ© floral
# 4                T-shirts                           T-shirt brodÃ© de fleurs
# ...                   ...                                                ...
# 14804      Soutiens-gorge  Soutiens-gorge respirants doublÃ©s de dentelle...
# 14805             Hoodies                 Oreilles Ã  capuche Cartoon Hoodie
# 14806         Pajama Sets  VÃªtements de dÃ©tente d'Ã©tÃ© Ã  imprimÃ© poi...
# 14807  Blouses & Chemises           Chemisier dÃ©contractÃ© Stringy Selvedge
# 14808  Pantalons & Shorts       Pantalon dÃ©contractÃ© de couleur unie Demin
#
# ...

# %%
FrenchClothing1.brand.value_counts()
# Out:
# ZANZEA          1683
# O-NEWE           869
# Celmia           492
# Gracila          417
# ZHI              310
# YOINS            254
# Middle East      230
# VONDA            224
# YCOSIC           178
# KISSLACE          43
# Miting            21
# SWIMMART          13
# FLORHO             9
# ME                 9
# ESCATCH            6
# HAHA-DLAMI         6
# Style Dome         6
# Veri Gude          5
# Yiranshini         4
# mancaihuixiu       4
# SUNNYME            4
# BIMEI              3
# Kenoce             3
#  Blioesy           3
# Auxo               3
# Cnfio              2
# Tangjie            2
# FULLGLADY          2
# MC CLAYN           2
# DAISSIONI          2
#  XLOONG            2
# iMars              1
# JAZZEVAR           1
# ACHIOOWA           1
# Kidsform           1
# FRMZ               1
# Name: brand, dtype: int64

# %% [markdown]
# ## Dropping the missing data

# %%
FrenchClothing1.dropna(inplace=True)
# Out:
# /var/folders/b6/tn8p_f9d1ls_4qs2b7h32md00000gn/T/ipykernel_1373/1154138827.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   FrenchClothing1.dropna(inplace=True)

# %% [markdown]
# ## Checking to see if it works

# %%
FrenchClothing1
# Out:
#                  subcategory  \
# 8         Pantalons & Shorts
# 9         Pantalons & Shorts
# 11           Vestes & Gilets
# 15        Pantalons & Shorts
# 16                  T-shirts
# ...                      ...
# 14792     Pantalons & Shorts
# 14795     Blouses & Chemises
# 14800  Robes dÃ©contractÃ©es
# 14803               Chemises
# 14805                Hoodies
#
#                                                    name  current_price  \
# 8                      Pantalon dÃ©contractÃ© Ã  fleurs          21.99
# 9      Pantalon dÃ©contractÃ© Ã  cordon de couleur unie          23.51
# 11          Vestes Ã  imprimÃ© floral de style ethnique          25.99
# 15                        Sarouel croisÃ© dÃ©contractÃ©          16.99
# 16                             T-shirt imprimÃ© poisson          17.99
# ...                                                 ...            ...
# 14792        Sarouel dÃ©contractÃ© Ã  taille Ã©lastique          23.99
# ...

# %% [markdown]
# ## Recode the clothing subcategory

# %%
def ClothingTypes (series):
    if series == "Pantalons and shorts, Denim & Jeans, Sweats, Shorts & Jupes, Jupes,Shorts,Leggings ": 
        return "Bottoms"
    if series == "Blouses and Chemises, T-shirts, Chemises, Tops, Tops courts, Kimonos & Tank Tops, Kimonos, DÃ©bardeurs ": 
        return "Tops"
    if series == "Combinaison & Salopette, Combinaisons & GrenouillÃ¨res, Une-PiÃ¨ces": 
        return "One-Pieces"
    if series == "Robes,Robes dÃ©contractÃ©es, Robes imprimÃ©es, Robes maxi, Robes vintage, Robes sexy, Robes en dentelle, Boho Dresses": 
        return "Dresses"
    if series == "Pajama sets, Nightgown, Pajamas Bottoms, Nightgown, Onesies": 
        return "Nightwear"
    if series == "Soutiens-gorge, Culotte haute, BrassiÃ¨res de sport, Corsets & Bustiers, Shapewears, Tankinis, Bikinis &Tankinis": 
        return "Under garments"
    if series == "SurvÃªtements, Jackets, Pulls & Cardigans, Cardigans, Cover-Ups, Vestes & Gilets, Hoodies , Hoodies & Sweatshirts, Sweatershirts, Cover-Ups, Sun Protective Outerwear": 
        return "Outerwear"
    if series == "Suits & Co-ords, Bas, Grande Taille": 
        return "Other"
FrenchClothing1["Clothing Types"] = FrenchClothing1["subcategory"].apply(ClothingTypes)
# Out:
# /var/folders/b6/tn8p_f9d1ls_4qs2b7h32md00000gn/T/ipykernel_1373/2770703106.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   FrenchClothing1["Clothing Types"] = FrenchClothing1["subcategory"].apply(ClothingTypes)

# %% [markdown]
# ## Check to see if it works

# %%
FrenchClothing1
# Out:
#                  subcategory  \
# 8         Pantalons & Shorts
# 9         Pantalons & Shorts
# 11           Vestes & Gilets
# 15        Pantalons & Shorts
# 16                  T-shirts
# ...                      ...
# 14792     Pantalons & Shorts
# 14795     Blouses & Chemises
# 14800  Robes dÃ©contractÃ©es
# 14803               Chemises
# 14805                Hoodies
#
#                                                    name  current_price  \
# 8                      Pantalon dÃ©contractÃ© Ã  fleurs          21.99
# 9      Pantalon dÃ©contractÃ© Ã  cordon de couleur unie          23.51
# 11          Vestes Ã  imprimÃ© floral de style ethnique          25.99
# 15                        Sarouel croisÃ© dÃ©contractÃ©          16.99
# 16                             T-shirt imprimÃ© poisson          17.99
# ...                                                 ...            ...
# 14792        Sarouel dÃ©contractÃ© Ã  taille Ã©lastique          23.99
# ...

# %% [markdown]
# ### looks like the code did not run the way it should. It is not necessary to recode the subcategory I just wanted to try it

# %% [markdown]
# ## Checking the columns

# %%
FrenchClothing1.columns
# Out:
# Index(['subcategory', 'name', 'current_price', 'raw_price', 'discount',
#        'amount of likes', 'is new', 'brand', 'variation_0_color',
#        'variation_1_color', 'url', 'id', 'model', 'Clothing Types'],
#       dtype='object')

# %% [markdown]
# ## Dropping unnessary columns

# %%
FrenchClothing1.drop(['url', 'model'], axis=1, inplace=True)
# Out:
# /var/folders/b6/tn8p_f9d1ls_4qs2b7h32md00000gn/T/ipykernel_1373/277241981.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   FrenchClothing1.drop(['url', 'model'], axis=1, inplace=True)

# %% [markdown]
# ## Checking to see if it works

# %%
FrenchClothing1
# Out:
#                  subcategory  \
# 8         Pantalons & Shorts
# 9         Pantalons & Shorts
# 11           Vestes & Gilets
# 15        Pantalons & Shorts
# 16                  T-shirts
# ...                      ...
# 14792     Pantalons & Shorts
# 14795     Blouses & Chemises
# 14800  Robes dÃ©contractÃ©es
# 14803               Chemises
# 14805                Hoodies
#
#                                                    name  current_price  \
# 8                      Pantalon dÃ©contractÃ© Ã  fleurs          21.99
# 9      Pantalon dÃ©contractÃ© Ã  cordon de couleur unie          23.51
# 11          Vestes Ã  imprimÃ© floral de style ethnique          25.99
# 15                        Sarouel croisÃ© dÃ©contractÃ©          16.99
# 16                             T-shirt imprimÃ© poisson          17.99
# ...                                                 ...            ...
# 14792        Sarouel dÃ©contractÃ© Ã  taille Ã©lastique          23.99
# ...
